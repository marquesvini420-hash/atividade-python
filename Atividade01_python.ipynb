# %% [markdown]
# <a href="https://colab.research.google.com/github/marquesvini420-hash/atividade-python/blob/main/Atividade01_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Atividade 01 -introdução ao python

# %%
print("ola mundo!")
print("Curso Técnico em Informática")
# Out:
# ola mundo!
# Curso Técnico em Informática

# %%
disciplina = input("Digite o nome da disciplina:")
conteudo = input("Digite o conteúdo estudado:")
atividade = input("Digite o número da atividade")
print("n---informações da atividade---")
print("Disciplinas:",disciplina)
print("Conteúdo:",conteudo)
print("Atividade:",atividade)
# Out:
# Digite o nome da disciplina:matematica
# Digite o conteúdo estudado:asss
# Digite o número da atividade23
# n---informações da atividade---
# Disciplinas: matematica
# Conteúdo: asss
# Atividade: 23

# %%
numero1 = 10
numero2 = 20
soma = numero1 + numero2
print("Resultado:",soma)
# Out:
# Resultado: 30

# %%
print("aprendendo versionamento  de porejetos!")
# Out:
# aprendendo versionamento  de porejetos!
